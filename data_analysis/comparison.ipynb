# %%
from data-loading/load_coordinates import coordinats
# Out:
# Running cells with 'group-24-bayesian-optimization (Python 3.12.10)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/katin/OneDrive - Danmarks Tekniske Universitet/6 semester/02463 Active Machine Learning and Agency/Bayesian optimaization/Group-24-Bayesian-Optimization/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %%
#loop over personerne
    #loop over gæt (start ved 4 da de første 4 er automatiske)
        #få acquisition function til at give prob of improvement for alle punkter 
        #(softmax til at gøre til sandsynligheder)
        #acquisition skal tage udgangspunkt i de punkter mennesket har valgt indtil videre.
        #sammenlign med menneskescore
